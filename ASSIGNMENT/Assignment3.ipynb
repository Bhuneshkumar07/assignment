# %% [markdown]
# ## Question 1

# %%
class Student:
    name = "Bhunesh"
    age = "21"
    course = "B.tech."
    
student1 = Student()
    
print("Name:",student1.name)
print("Age:",student1.age)
print("Course:",student1.course)
# Out:
# Name: Bhunesh
# Age: 21
# Course: B.tech.

# %% [markdown]
# ## Question 2

# %%
class Car:
    def __init__(self,brand,model,price):
        self.brand = brand
        self.model = model
        self.price = price
        
car1=Car("suzuki","alto","300000") 
car2=Car("hundai","santro",400000) 

print(car1.brand,car1.model,car1.price)
print(car2.model,car2.model,car2.price)
# Out:
# suzuki alto 300000
# santro santro 400000

# %% [markdown]
# ## Question 3

# %%
class Employee:
    def __init__(self,employee_id,name,salary):
        self.employee_id=employee_id
        self.name=name
        self.salary=salary
        
employee1=Employee(69,"Sakira","6000")

print("ID:",employee1.employee_id)
print("Name:",employee1.name)
print("Salary",employee1.salary)
# Out:
# ID: 69
# Name: Sakira
# Salary 6000

# %% [markdown]
# ## Question 4

# %%
class Rectangle:
    def __init__(self,length,width):
        self.length=length
        self.width=width
        
    def area(self):
         print("Area =",self.length * self.width)
    
r1 = Rectangle(10,5)
r1.area()
# Out:
# Area = 50

# %% [markdown]
# ## Question 5

# %%
class Circle:
    def __init__(self,radius):
        self.radius=radius
        
    def area(self):
        area= 3.14*self.radius*self.radius
        print("Area:",area)
    
c1 = Circle(7)
c1.area()
# Out:
# Area: 153.86

# %% [markdown]
# ## Question 6

# %%
class BankAccount:
    def __init__(self, account_holder, balance):
        self.account_holder = account_holder
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount
        print(f"Deposited: {amount}")
        print(f"Updated Balance: {self.balance}")

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            print(f"Withdrawn: {amount}")
            print(f"Updated Balance: {self.balance}")
        else:
            print("Insufficient Balance")


acc = BankAccount("Rahul", 5000)

acc.deposit(1000)
acc.withdraw(2000)
# Out:
# Deposited: 1000
# Updated Balance: 6000
# Withdrawn: 2000
# Updated Balance: 4000

# %% [markdown]
# ## Question7

# %%
class Animal:
    def sound(self):
        print("Animal makes a sound")


class Dog(Animal):
    def sound(self):
        print("Bark")


d = Dog()
d.sound()
# Out:
# Bark

# %% [markdown]
# ## Question 8

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age


class Student(Person):
    def __init__(self, name, age, roll_number):
        super().__init__(name, age)
        self.roll_number = roll_number

    def display(self):
        print("Name:", self.name)
        print("Age:", self.age)
        print("Roll Number:", self.roll_number)


# Object Creation
s = Student("Amit", 20, 101)

s.display()
# Out:
# Name: Amit
# Age: 20
# Roll Number: 101

# %% [markdown]
# ## Question 9

# %%
class Calculator:
    def add(self, a, b):
        return a + b

    def subtract(self, a, b):
        return a - b

    def multiply(self, a, b):
        return a * b

    def divide(self, a, b):
        if b != 0:
            return a / b
        return "Cannot divide by zero"



num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

calc = Calculator()

print("Addition:", calc.add(num1, num2))
print("Subtraction:", calc.subtract(num1, num2))
print("Multiplication:", calc.multiply(num1, num2))
print("Division:", calc.divide(num1, num2))
# Out:
# Addition: 30.0
# Subtraction: -10.0
# Multiplication: 200.0
# Division: 0.5

# %% [markdown]
# ## Question 10

# %%
class LibraryBook:
    def __init__(self, book_name, author, price):
        self.book_name = book_name
        self.author = author
        self.price = price

    def display(self):
        print("Book Name:", self.book_name)
        print("Author:", self.author)
        print("Price:", self.price)


# Object Creation
book = LibraryBook("English", "RAM", 499)

book.display()
# Out:
# Book Name: English
# Author: RAM
# Price: 499
