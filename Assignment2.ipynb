# %% [markdown]
# ## Question1

# %%
my_tpl = (10,20,30,40,50)
print(my_tpl)
# Out:
# (10, 20, 30, 40, 50)

# %%
print("First element:",my_tpl[0])
# Out:
# First element: 10

# %%
print("Last element:",my_tpl[-1])
# Out:
# Last element: 50

# %%
print("Length of tuple:",len(my_tpl))
# Out:
# Length of tuple: 5

# %%
print("Elements from index 1 to 3:", my_tpl[1:4])
# Out:
# Elements from index 1 to 3: (20, 30, 40)

# %% [markdown]
# ## Question2

# %%
fruits = ("apple","banana","mango","orange")

print(fruits)
# Out:
# ('apple', 'banana', 'mango', 'orange')

# %%
print("Second fruit:",fruits[1])
# Out:
# Second fruit: banana

# %%
print("Last two fruits:",fruits[-2:])
# Out:
# Last two fruits: ('mango', 'orange')

# %%
print("Total number of fruits:",len(fruits))
# Out:
# Total number of fruits: 4

# %% [markdown]
# ## Question3

# %%
numbers = {10,20,30,40,50}
print(numbers)
# Out:
# {50, 20, 40, 10, 30}

# %%
print("complete set:",numbers)
# Out:
# complete set: {50, 20, 40, 10, 30}

# %%
print("Length of set:",len(numbers))
# Out:
# Length of set: 5

# %%
print("Check 30 is present:",30 in numbers)
# Out:
# Check 30 is present: True

# %% [markdown]
# ## Question4

# %%
set1 = {1,2,3,4}
set2 = {3,4,5,6}

print("Union:",set1 | set2)
print("Intersection:",set1 & set2)
# Out:
# Union: {1, 2, 3, 4, 5, 6}
# Intersection: {3, 4}

# %% [markdown]
# ## Question5

# %%
student = {"name":"Kriti","age":20,"course":"Python"}
print("Complete dictionary:",student)
print("Student name:",student["name"])
print("student age:",student["age"])
# Out:
# Complete dictionary: {'name': 'Kriti', 'age': 20, 'course': 'Python'}
# Student name: Kriti
# student age: 20

# %% [markdown]
# ## Question6

# %%
numbers = [12,45,7,23,56,89,34]
print("Largest number:",max(numbers))
second_largest = sorted(numbers)[-2]
print("Second largest:",second_largest)
print("Smallest number:",min(numbers))
# Out:
# Largest number: 89
# Second largest: 56
# Smallest number: 7

# %%
arr = [10,20,30,40,50,60]
def reverse_lst(lst):
    return lst[::-1]
print("Original arr:",arr)
print("Reversed arr:",reverse_lst(arr))
# Out:
# Original arr: [10, 20, 30, 40, 50, 60]
# Reversed arr: [60, 50, 40, 30, 20, 10]

# %% [markdown]
# ## Question7

# %%
data = (5, 10, 15, 20, 25, 30, 35)

count = 0

for num in data:
    if num % 5 == 0:
        count += 1




print("Count divisible by 5:", count)
print("Sum:", sum(data))
print("Average:", sum(data)/ len(data))
# Out:
# Count divisible by 5: 7
# Sum: 140
# Average: 20.0

# %% [markdown]
# ## Question8

# %%
students = {
    "Aman": 78,
    "Riya": 92,
    "Kriti": 88,
    "Rahul": 95
}


highest = max(students, key=students.get)
lowest = min(students, key=students.get)

print("Highest Marks:", highest, students[highest])
print("Lowest Marks:", lowest, students[lowest])
# Out:
# Highest Marks: Rahul
# Lowest Marks: Aman 78

# %%
students = {
    "Aman": 78,
    "Riya": 92,
    "Kriti": 88,
    "Rahul": 95
}

print("Students scoring more than 85:")

for name, marks in students.items():
    if marks > 85:
        print(name, ":", marks)
# Out:
# Students scoring more than 85:
# Riya : 92
# Kriti : 88
# Rahul : 95

# %% [markdown]
# ## Question9

# %%
def count_frequency(arr):
    freq = {}

    for item in arr:
        if item in freq:
            freq[item] += 1
        else:
            freq[item] = 1

    for key, value in freq.items():
        print(key, "->", value, "times")


arr = [1, 2, 2, 3, 1, 4, 2]

count_frequency(arr)
# Out:
# 1 -> 2 times
# 2 -> 3 times
# 3 -> 1 times
# 4 -> 1 times

# %% [markdown]
# ## Question10

# %%
def find_duplicates(arr):
    duplicates = set()

    for item in arr:
        if arr.count(item) > 1:
            duplicates.add(item)

    print("Duplicate elements are:")

    for item in duplicates:
        print(item)


arr = [10, 20, 30, 20, 40, 10, 50, 30]

find_duplicates(arr)
# Out:
# Duplicate elements are:
# 10
# 20
# 30
